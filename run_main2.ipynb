# %%
import main
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
liver_ast = {0: [0, 0.0001], 4: [142.78921410, 0.2771], 24: [46.165639, 0.1425], 144: [17.208548, 0.127494]}
liver_simind = {0: [0, 0.0001], 4: [148.20992, 0.35580], 24: [49.706194, 0.172591977], 144: [19.871, 0.068]} 

spleen_ast = {0: [0, 0.0001], 4: [8.72699784, 0.0919], 24: [1.655212, 0.0240], 144: [0.609914, 0.0134]}
spleen_simind = {0: [0, 0.0001],4: [9.36466, 0.10608], 24: [1.884420, 0.030228883], 144: [0.78154, 0.01456]} 

right_kid_ast = { 0: [0, 0.0001],4: [24.56420400, 0.1977], 24: [12.436020, 0.2114], 144: [10.01794, 0.1501]}
right_kid_simind = {0: [0, 0.0001], 4: [23.00740, 0.23072], 24: [14.380454, 0.232477735], 144: [10.16740, 0.17224]} 

left_kid_ast = {0: [0, 0.0001], 4: [31.30303600, 0.2839], 24: [20.936659, 0.2334], 144: [13.599456, 0.1840]}
left_kid_simind = {0: [0, 0.0001], 4: [33.16916, 0.34229], 24: [23.353949, 0.285811059], 144: [14.63627, 0.23408]} 

bladder_ast= {0: [0, 0.0001], 4: [111.91751340, 0.8617], 24: [18.367083, 0.3783], 144: [11.597635, 0.3216]}
bladder_simind= {0: [0, 0.0001], 4: [118.21716, 1.14787], 24: [19.074732, 0.401981496], 144: [11.68113, 0.26584]} 

tumor_1_ast = {0: [0, 0.0001], 4: [12.05435340, 0.8645],  24: [11.557187, 0.8311], 144: [7.904785, 0.7275]}
tumor_1_simind = {0: [0, 0.0001], 4: [8.37904, 0.18522], 24: [7.037053, 0.239833797], 144: [6.07000, 0.23820]} 

tumor_2_ast = {0: [0, 0.0001], 4: [0.36787086, 0.0074], 24: [0.416158, 0.0154], 144: [0.369232, 0.0259]}
tumor_2_simind = {0: [0, 0.0001], 4: [0.39118, 0.01555], 24: [0.431094, 0.011323142], 144: [0.37550, 0.01785]} 

remaining_ast= {0: [0, 0.0001], 4: [1137.8, 6], 24: [525.87, 5.5], 144: [231.24, 2.5]}
remaining_simind= {0: [0, 0.0001], 4: [1243.87, 6], 24: [597.75, 5], 144: [276.38, 2.5]} 

main_dict= {'liver':[liver_ast, liver_simind], 'spleen':[spleen_ast, spleen_simind], 
			 'right kidney': [right_kid_ast, right_kid_simind], 'left kidney': [left_kid_ast, left_kid_simind], 
			 'tumor1': [tumor_1_ast, tumor_1_simind], 'tumor2': [tumor_2_ast, tumor_2_simind],
             'remaining':[remaining_ast, remaining_simind], 'bladder':[bladder_ast, bladder_simind]}

# %%
main.main(main_dict, 
     original_24h_path= "E:\\tese_mestrado\\patients_study\\p8\\volumes_alinhados\\p8_24h.nrrd",
     simulated_24h_path= "E:\\tese_mestrado\\patients_study\\p8\\volumes_alinhados\\recon_simind_24h.nii",
     seg_path= "E:\\tese_mestrado\\patients_study\\p8\\volumes_alinhados\\seg_total.nrrd",
     output_path= "E:\\teste_git",
     administered_activity=6810)
# Out:
# Processing VOI: liver
#   Fit achieved at i=1340 with R²=0.999904
#   Best fit: i=1340, R²=0.999904
# Original activity: 7536.53 MBq*h
# Simulated activity: 8503.16 MBq*h
# Difference(%): 12.83
# Processing VOI: spleen
#   Best fit: i=15560, R²=0.977423
# Original activity: 139.89 MBq*h
# Simulated activity: 381.46 MBq*h
# Difference(%): 172.69
# Processing VOI: right kidney
#   Fit achieved at i=20880 with R²=0.999943
#   Best fit: i=20880, R²=0.999943
# Original activity: 10599.97 MBq*h
# Simulated activity: 5477.87 MBq*h
# Difference(%): -48.32
# Processing VOI: left kidney
#   Fit achieved at i=3110 with R²=0.999909
#   Best fit: i=3110, R²=0.999909
# Original activity: 6183.49 MBq*h
# Simulated activity: 6518.29 MBq*h
# Difference(%): 5.41
# Processing VOI: tumor1
#   Fit achieved at i=10310 with R²=0.999995
#   Best fit: i=10310, R²=0.999995
# Original activity: 3931.92 MBq*h
# Simulated activity: 5736.15 MBq*h
# Difference(%): 45.89
# Processing VOI: tumor2
# ...

# %%
liver_ast = {0: [0, 0.0001], 4: [124.38959072503, 1.537367], 24: [37.7515387711174, 0.607763], 120: [8.9943168868411, 0.127494]}
liver_simind = {0: [0, 0.0001], 4: [125.111247, 1.628772], 24: [38.748669, 0.671705], 120: [9.128179, 0.136377]}

spleen_ast = {0: [0, 0.0001], 4: [15.776776, 0.337358], 24: [3.919345, 0.177488], 120: [0.694416, 0.021221]}
spleen_simind = {0: [0, 0.0001],4: [13.726647, 0.171488], 24: [3.986914, 0.240543], 120: [0.637171, 0.017479]}

right_kid_ast = { 0: [0, 0.0001],4: [80.990723, 0.446256], 24: [69.235484, 0.803898], 120: [21.090898, 0.241224]}
right_kid_simind = {0: [0, 0.0001], 4: [84.153715, 0.499432], 24: [86.048657, 0.671325], 120: [25.316094, 0.230845]}

left_kid_ast = {0: [0, 0.0001], 4: [75.539789, 0.517270], 24: [61.183383, 0.707927], 120: [16.770402, 0.218478]}
left_kid_simind = {0: [0, 0.0001], 4: [81.172688, 0.627032], 24: [70.507004, 0.749137], 120: [20.165298, 0.232353]}

bladder_ast= {0: [0, 0.0001], 4: [106.911, 0.617], 24: [58.616, 0.8783], 120: [6.7627, 0.129]}
bladder_simind= {0: [0, 0.0001], 4: [100.1288, 1.127], 24: [59.9237, 1.608795], 120: [7.6607, 0.144838]}


tumor_1_ast = {0: [0, 0.0001], 4: [5.0853, 0.1842], 24: [6.6749, 0.36976], 120: [3.08334, 0.21380]}
tumor_1_simind = {0: [0, 0.0001], 4: [4.26577, 0.0867], 24: [5.4818710, 0.18964], 120: [2.9927, 0.17102]}

tumor_2_ast = {0: [0, 0.0001], 4: [0.76745, 0.03486], 24: [2.16126, 0.14533], 120: [1.29101, 0.10229]}
tumor_2_simind = {0: [0, 0.0001], 4: [0.680092, 0.01377], 24: [1.9648, 0.08960], 120: [1.35214, 0.09063]}

remaining_ast= {0: [0, 0.0001], 4: [1686.4, 6], 24: [648.04, 5.5], 120: [98.090, 2.5]}
remaining_simind= {0: [0, 0.0001], 4: [1748.83, 6], 24: [683.55, 5], 120: [122.97, 2.5]}

main_dict= {'liver':[liver_ast, liver_simind], 'spleen':[spleen_ast, spleen_simind], 
			 'right kidney': [right_kid_ast, right_kid_simind], 'left kidney': [left_kid_ast, left_kid_simind], 
			 'tumor1': [tumor_1_ast, tumor_1_simind], 'tumor2': [tumor_2_ast, tumor_2_simind],
             'remaining':[remaining_ast, remaining_simind], 'bladder':[bladder_ast, bladder_simind]}

# %%
main.main(main_dict, 
	 original_24h_path= "E:\\tese_mestrado\\patients_study\\p1\\volumes_finais\\spect_or_24h.nrrd",
     simulated_24h_path= "C:\\simind\\patient_study\\spect_simind_24h_display.nii",
     seg_path= "E:\\tese_mestrado\\patients_study\\p1\\volumes_finais\\seg_spect_24h_marta.seg.nrrd",
     output_path= "E:\\CODIGO_USADO_TESE\\p1",
     administered_activity=6783)
# Out:
# Processing VOI: liver
#   Fit achieved at i=1240 with R²=0.999976
#   Best fit: i=1240, R²=0.999976
# Original activity: 4260.66 MBq*h
# Simulated activity: 4372.41 MBq*h
# Difference(%): 2.62
# Processing VOI: spleen
#   Error at i=26250: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
#   Error at i=27490: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
#   Error at i=27530: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# ...
